# %%
with open('sample.txt') as text:
    message = text.read()
    print(message)
# Out:
# This is just a sample.

# %%
message
# Out:
# 'This is just a sample.'

# %%
with open('sample.txt', 'w') as file:
    file.write('I am Machine Learning Engineer')

# %%
with open('sample.txt') as file:
    message = file.read()
    print(message)
# Out:
# I am Machine Learning Engineer
