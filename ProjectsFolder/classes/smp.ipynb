# %%
with open('sample.txt') as text:
    message = text.read()
    print(message)
# Out:
# This is just a sample.

# %%
with open('sample.txt') as text:
    message = text.read()
    print(message)
# Out:
# This is just a sample.
