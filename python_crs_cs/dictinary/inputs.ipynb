# %%
message = input('Tell me something, and I will repeat it back to you: ')
message
# Out:
# 'Hi I am just testing'

# %%
number = 1

while number <= 6:
    print(number)
    number += 1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
prompt = 'Tell me something, and I will repeat it back to you: '
prompt += "\nEnter 'quit' to end the program. "

message = ''

while message != 'quit':
    message = input(prompt)
    if message == 'quit':
        pass
    else:
        print(message)
# Out:
# Hello
# Hi

# %%
# Same problem but different solution

prompt = 'Tell me something, and I will repeat it back to you: '
prompt += "\nEnter 'quit' to end the program. "

message = ''

while message != 'quit':
    message = input(prompt)
    if message != 'quit':
        print(message)
# Out:
# Hello
# Hello again

# %%
c_number = 0

while c_number < 10:
    c_number += 1
    if c_number % 2 == 0:
        continue
    print(c_number)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
unconfirmed_users = ['alice', 'brian', 'candace', 'alamin', 'musa']
current_users = []

while unconfirmed_users:
    current_user = unconfirmed_users.pop()
    print("Verifying user: " + current_user.title())
    current_users.append(current_user)

print("\nThe following users have been confirmed:")
for user in current_users:
    print(user.title())
# Out:
# Verifying user: Musa
# Verifying user: Alamin
# Verifying user: Candace
# Verifying user: Brian
# Verifying user: Alice
#
# The following users have been confirmed:
# Musa
# Alamin
# Candace
# Brian
# Alice

# %%
pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
print(pets)

while 'cat' in pets:
    pets.remove('cat')

print(pets)
# Out:
# ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# ['dog', 'dog', 'goldfish', 'rabbit']

# %%
responses = {}


# Set a flag to indicate that polling is active.
polling_active = True

while polling_active:
    # Prompt for the person's name and response.
    name = input('What is your name? ')
    response = input("Which mountain would you like to climb someday? ")
    responses[name] = response

    repeat = input("Would you like to let another person respond? (yes/ no) ").lower()
    if repeat == 'no':
        polling_active = False

# Polling is complete. Show the results.
print("\n--- Poll Results ---")
for name, response in responses.items():
    print(name + " would like to climb " + response + ".")
# Out:
# --- Poll Results ---
# Alamin would like to climb cape town.
# nafisa would like to climb cape town.
# frances would like to climb pritoria.

# %%
def favorite_book(book:str)->str:
    '''This woll return the name of the favorite book'''
    favorite_b = f'''I really like the book: {book}. The book Teaches me a lot.'''
    return favorite_b

favorite_book('Atomic Habit')
# Out:
# 'I really like the book: Atomic Habit. The book Teaches me a lot.'

# %%
org_dict = {}

def add_key_value(value_1, value_2):
    add_val = {'firs_name': value_1, 
               'last_name': value_2}
    org_dict['first_name'] = add_val['firs_name']
    org_dict['last_name'] = add_val['last_name']
    return org_dict


add_key_value(value_1='musa', value_2='Nababa')
org_dict
# Out:
# {'first_name': 'musa', 'last_name': 'Nababa'}

# %%
l = [2, 2, 2, 2, 2, 2, 3]

s = l[:]
s[3]
# Out:
# 2

# %%
def course_score(registered:int, *courses):
    message_1 = f'You registered {registered} courses.'
    print(message_1)
    print('\n Your CRF should be like: ')
    for i in courses:
        print('\t- ' + i)

course_score(10, 'Thermo', 'Mechanic', 'Fluids')
# Out:
# You registered 10 courses.
#
#  Your CRF should be like:
# 	- Thermo
# 	- Mechanic
# 	- Fluids
